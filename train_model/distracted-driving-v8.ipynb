# %% [markdown]
# # Model training report
#
# This notebook was written to be run on google colab, using the available GPU to train the model on custom dataset.

# %% [markdown]
# ## Install Dependencies and Dataset

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 691.9/691.9 kB 7.7 MB/s eta 0:00:00
# ...

# %%
# !curl -L "https://universe.roboflow.com/ds/4rYTP681MF?key=cYrrejGxpc" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#  extracting: train/labels/img_2998_jpg.rf.5beba2cd0e2d88e12c8de84042deda10.txt
#  extracting: train/labels/img_29993_jpg.rf.780e8134e6bbeeae55e27f7e90919603.txt
#  extracting: train/labels/img_2999_jpg.rf.08f0aa90e36994a6d1566d4cee4d65c9.txt
#  extracting: train/labels/img_3000_jpg.rf.7772623e11225499521339fa77320d83.txt
#  extracting: train/labels/img_30018_jpg.rf.11d6bcf71dec1012c8e9752392ec128e.txt
#  extracting: train/labels/img_3004_jpg.rf.6aa2aed0886e255e0e5ed540e051aea5.txt
#  extracting: train/labels/img_30056_jpg.rf.6cdf83be605dc696f55568a97b8c99d6.txt
#  extracting: train/labels/img_30060_jpg.rf.d96e32becdbafb392240340551bb965d.txt
#  extracting: train/labels/img_30061_jpg.rf.6327b9aaf60818377563aab84bee4efb.txt
#  extracting: train/labels/img_30064_jpg.rf.8760bc3fe315d5563126e90e09c3faca.txt
#  extracting: train/labels/img_3006_jpg.rf.cbe34edb08965400903b6764418310ba.txt
# ...

# %% [markdown]
# ## Import existing models

# %%
from ultralytics import YOLO
from google.colab import files, drive
import shutil

drive.mount('/content/drive')

# custom_model = YOLO("distracted-driving.pt") # Pre-trained model based on the small base model from Yolo ("yolov8s.pt")
new_model = YOLO("yolov8s.pt")
#new_model = YOLO("yolov8m.pt")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 199MB/s]

# %% [markdown]
# ## Train model on dataset, export and save

# %%
results = new_model.train(data='data.yaml', epochs=300, imgsz=640)
new_model.export(format="onnx")
#files.download("/content/runs/detect/train/weights/best.onnx")
#files.download("/content/runs/detect/train/weights/best.pt")
shutil.copy("/content/runs/detect/train2/weights/best.onnx", "/content/drive/My Drive/Colab Notebooks/distracted-driving-small.onnx")
shutil.copy("/content/runs/detect/train2/weights/best.pt", "/content/drive/My Drive/Colab Notebooks/distracted-driving-small.pt")
# Out:
# New https://pypi.org/project/ultralytics/8.0.238 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.237 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %% [markdown]
# ## Train model on dataset, export and save

# %%
results = new_model.train(data='data.yaml', epochs=300, imgsz=640)
new_model.export(format="onnx")
#files.download("/content/runs/detect/train2/weights/best.onnx")
#files.download("/content/runs/detect/train2/weights/best.pt")
shutil.copy("/content/runs/detect/train/weights/best.onnx", "/content/drive/My Drive/Colab Notebooks/distracted-driving-medium.onnx")
shutil.copy("/content/runs/detect/train/weights/best.pt", "/content/drive/My Drive/Colab Notebooks/distracted-driving-medium.pt")
# Out:
# Ultralytics YOLOv8.0.237 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...
